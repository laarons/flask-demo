# %%
import numpy as np
import quandl
import requests
import json
import pandas
from pandas import *

# %%
quandl.ApiConfig.api_key = 'gJCP3YaHM38A6tRTRpSD'

# %%
url_pref = "https://www.quandl.com/api/v3/datasets/WIKI/"
url_predate = "/data.json"
par_start = "&api_key=" + quandl.ApiConfig.api_key + "&start_date="
par_middate = "&end_date="
par_end = "&order=asc"

# %%
stck_symb = 'GOOG'
date1 = '2015-01-01'
date2 = '2016-01-31'

# %%
search_url = url_pref + stck_symb + url_predate
search_par = par_start + date1 + par_middate + date2 + par_end

# %%
search_r = requests.get(search_url,params=search_par)
search_data = search_r.json()
search_r.status_code
# Out:
# INFO:requests.packages.urllib3.connectionpool:Starting new HTTPS connection (1): www.quandl.com
# 200

# %%
df = DataFrame(search_data)
df2 = DataFrame(df['dataset_data']['data'],columns = df['dataset_data']['column_names'])

# %%
datetime.strptime(df2['Date'][0],'%Y-%m-%d')
# Out:
# datetime.datetime(2016, 1, 4, 0, 0)

# %%
import bokeh

# %%
from bokeh.layouts import gridplot
from bokeh.plotting import figure, show, output_file

# %%
datause = 'Close'

# %%
p1 = figure(x_axis_type="datetime", title="Stock Closing Prices")

# %%
p1.grid.grid_line_alpha=0.3
p1.xaxis.axis_label = 'Date'
p1.yaxis.axis_label = 'Price'

# %%
from datetime import datetime

# %%
pandas.to_datetime(df2['Date'])
# Out:
# 0    2016-01-04
# 1    2016-01-05
# 2    2016-01-06
# 3    2016-01-07
# 4    2016-01-08
# 5    2016-01-11
# 6    2016-01-12
# 7    2016-01-13
# 8    2016-01-14
# 9    2016-01-15
# 10   2016-01-19
# 11   2016-01-20
# 12   2016-01-21
# 13   2016-01-22
# 14   2016-01-25
# 15   2016-01-26
# 16   2016-01-27
# 17   2016-01-28
# 18   2016-01-29
# Name: Date, dtype: datetime64[ns]

# %%
p1.line(pandas.to_datetime(df2['Date']),df2[datause])
# Out:
# GlyphRenderer(id='9cfc1dc5-ad94-481e-9d13-dc3974916c87', ...)

# %%
from bokeh.io import output_notebook

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="75dd2fee-1b50-4cd8-807d-d120ace05e6b">Loading BokehJS ...</span>
#     </div>

# %%
show(p1)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="60cd9a3d-8d70-4076-b992-293c34dc3f79"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
# ...

# %%
df2
# Out:
#            Date    Open      High       Low   Close     Volume  Ex-Dividend  \
# 0    2015-01-02  529.01  531.2700  524.1000  524.81  1446662.0          0.0
# 1    2015-01-05  523.26  524.3300  513.0600  513.87  2054238.0          0.0
# 2    2015-01-06  515.00  516.1750  501.0500  501.96  2891950.0          0.0
# 3    2015-01-07  507.00  507.2440  499.6500  501.10  2059366.0          0.0
# 4    2015-01-08  497.99  503.4800  491.0000  502.68  3344395.0          0.0
# 5    2015-01-09  504.76  504.9200  494.7900  496.17  2054956.0          0.0
# 6    2015-01-12  494.94  495.9760  487.5600  492.55  2320446.0          0.0
# 7    2015-01-13  498.84  502.9800  492.3900  496.18  2365687.0          0.0
# 8    2015-01-14  494.65  503.2300  493.0000  500.87  2229638.0          0.0
# 9    2015-01-15  505.57  505.6800  497.7600  501.79  2711355.0          0.0
# 10   2015-01-16  500.01  508.1900  500.0000  508.08  2292043.0          0.0
# ...

# %%
import wtforms
